# %%
import math
import warnings

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

from sklearn import linear_model
from sklearn.cross_decomposition import PLSRegression

sns.set_style("white")
warnings.filterwarnings(action="ignore", module="scipy", message="internal gelsd")

# %%
n = 1000
p = 10

X = np.random.normal(size = n*p).reshape((n,p))

y = X[:,0] + 2 * X[:,1] + 2 * X[:,4] * X[:,5] + np.random.normal(size=n*1) + 5

# %%
f, ax = plt.subplots(figsize=(12,9))

corrmat = pd.DataFrame(np.insert(X,0,y,axis=1)).corr()

sns.heatmap(corrmat, vmax=.8, square=True)
plt.show()

# %%
regr = linear_model.LinearRegression()
regr.fit(X,y)

Y_pred = regr.predict(X)
print("R-squared regression: ", regr.score(X,y))

pls1 = PLSRegression(n_components=3)

pls1.fit(X,y)

Y_PLS_pred = pls1.predict(X)
print("R-squared PLSR: ", pls1.score(X,y))

plt.scatter(Y_pred,Y_PLS_pred)
plt.xlabel("Predicted by original 10 features")
plt.ylabel("Predicted by 3 features")
plt.title("Comparing LR and PLSR predictions")
plt.grid()
plt.show()
# Out:
# R-squared regression:  0.47821092455944797
# R-squared PLSR:  0.47821075147237

# %%
pls2 = PLSRegression(n_components=5)

pls2.fit(X,y)

Y_PLS_pred = pls2.predict(X)
print("R-squared PLSR: ", pls2.score(X,y))

plt.scatter(Y_pred,Y_PLS_pred)
plt.xlabel("Predicted by original 10 features")
plt.ylabel("Predicted by 5 features")
plt.title("Comparing LR and PLSR predictions")
plt.show()
# Out:
# R-squared PLSR:  0.47821092455718306

# %%
pls3 = PLSRegression(n_components=2)

pls3.fit(X,y)

Y_PLS_pred = pls3.predict(X)
print("R-squared PLSR: ", pls3.score(X,y))

plt.scatter(Y_pred,Y_PLS_pred)
plt.xlabel("Predicted by original 10 features")
plt.ylabel("Predicted by 2 features")
plt.title("Comparing LR and PLSR predictions")
plt.grid()
plt.show()
# Out:
# R-squared PLSR:  0.4781859736135867

# %%
pls4 = PLSRegression(n_components=1)

pls4.fit(X,y)

Y_PLS_pred = pls4.predict(X)
print("R-squared PLSR: ", pls4.score(X,y))

plt.scatter(Y_pred,Y_PLS_pred)
plt.xlabel("Predicted by original 10 features")
plt.ylabel("Predicted by 1 features")
plt.title("Comparing LR and PLSR predictions")
plt.grid()
plt.show()
# Out:
# R-squared PLSR:  0.4741767079190324
